# %%
import pandas as pd
import seaborn as sns
from matplotlib import pyplot as plt

# %%
df_wm_sales_e=pd.read_csv('data/sales_train_evaluation.csv')

# %%
df_wm_sales_e.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30490 entries, 0 to 30489
# Columns: 1947 entries, id to d_1941
# dtypes: int64(1941), object(6)
# memory usage: 452.9+ MB

# %%
df_wm_sales_v=pd.read_csv('data/sales_train_validation.csv')
df_wm_sales_v.info() #validation has less day values (1942 vs 1913). so lets use evaluation data.
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30490 entries, 0 to 30489
# Columns: 1919 entries, id to d_1913
# dtypes: int64(1913), object(6)
# memory usage: 446.4+ MB

# %%
df_wm_sales_e.columns
# Out:
# Index(['id', 'item_id', 'dept_id', 'cat_id', 'store_id', 'state_id', 'd_1',
#        'd_2', 'd_3', 'd_4',
#        ...
#        'd_1932', 'd_1933', 'd_1934', 'd_1935', 'd_1936', 'd_1937', 'd_1938',
#        'd_1939', 'd_1940', 'd_1941'],
#       dtype='object', length=1947)

# %%
print(f'Number of items: {df_wm_sales_e["item_id"].nunique()}')
print(f'Number of departments: {df_wm_sales_e["dept_id"].nunique()}')
print(f'Number of categories: {df_wm_sales_e["cat_id"].nunique()}')
print(f'Number of stores: {df_wm_sales_e["store_id"].nunique()}')
print(f'Number of states: {df_wm_sales_e["state_id"].nunique()}')
# Out:
# Number of items: 3049
# Number of departments: 7
# Number of categories: 3
# Number of stores: 10
# Number of states: 3

# %%
df_wm_sales_e["cat_id"].value_counts()
# Out:
# cat_id
# FOODS        14370
# HOUSEHOLD    10470
# HOBBIES       5650
# Name: count, dtype: int64

# %%
df_wm_sales_e["state_id"].value_counts()
# Out:
# state_id
# CA    12196
# TX     9147
# WI     9147
# Name: count, dtype: int64

# %% [markdown]
# import pandas as pd
#
# # Start from your current df_wm_sales_e
# df_sales_wide = df_wm_sales_e.copy()
# # 1) Filter by category
# cat = "FOODS"
# df_cat = df_sales_wide[df_sales_wide["cat_id"] == cat].copy()
#
# # 2) Filter by state
# state = "CA"
# df_state = df_cat[df_cat["state_id"] == state].copy()
#
# # 3) Choose a few stores in that state (still in wide format)
# top_stores = df_state["store_id"].value_counts().index[:3]
# df_stores = df_state[df_state["store_id"].isin(top_stores)].copy()
#
# # 4) Pick top-N items by total sales across all days
# day_cols = [c for c in df_stores.columns if c.startswith("d_")]
#
# df_stores["total_sales"] = df_stores[day_cols].sum(axis=1)
# df_top = df_stores.sort_values("total_sales", ascending=False).head(30).copy()
#
# # Drop helper column if you like
# df_top = df_top.drop(columns=["total_sales"])

# %% [markdown]
# df_sales_wide = df_wm_sales_e.copy()
# # 1) Filter by category
# cat = "FOODS"
# df_cat = df_sales_wide[df_sales_wide["cat_id"] == cat].copy()
#
# # 2) Filter by state
# state = "WI"
# df_state = df_cat[df_cat["state_id"] == state].copy()
#
# # 3) Choose a few stores in that state (still in wide format)
# top_stores = df_state["store_id"].value_counts().index[:3]
# df_stores = df_state[df_state["store_id"].isin(top_stores)].copy()
#
# # 4) Pick top-N items by total sales across all days
# day_cols = [c for c in df_stores.columns if c.startswith("d_")]
#
# df_stores["total_sales"] = df_stores[day_cols].sum(axis=1)
# df_top_f_wi = df_stores.sort_values("total_sales", ascending=False).head(30).copy()
#
# # Drop helper column if you like
# df_top_f_wi = df_top_f_wi.drop(columns=["total_sales"])

# %%
day_cols = [c for c in df_top.columns if c.startswith("d_")]

df_food_ca = df_top.melt(
    id_vars=["id", "item_id", "dept_id", "cat_id", "store_id", "state_id"],
    value_vars=day_cols,
    var_name="d",
    value_name="sales"
)

# %%
print(f'Number of items: {df_food_ca["item_id"].nunique()}')
print(f'Number of departments: {df_food_ca["dept_id"].nunique()}')
print(f'Number of categories: {df_food_ca["cat_id"].nunique()}')
print(f'Number of stores: {df_food_ca["store_id"].nunique()}')
print(f'Number of states: {df_food_ca["state_id"].nunique()}')
# Out:
# Number of items: 20
# Number of departments: 2
# Number of categories: 1
# Number of stores: 3
# Number of states: 1

# %%
df.isna().sum()
# Out:
# id                  0
# item_id             0
# dept_id             0
# cat_id              0
# store_id            0
# state_id            0
# d                   0
# sales               0
# date                0
# wm_yr_wk            0
# weekday             0
# wday                0
# month               0
# year                0
# event_name_1    53490
# event_type_1    53490
# event_name_2    58110
# event_type_2    58110
# snap_CA             0
# snap_TX             0
# snap_WI             0
# dtype: int64

# %%
sell_prices=pd.read_csv('data/sell_prices.csv')

# %%
sell_prices.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6841121 entries, 0 to 6841120
# Data columns (total 4 columns):
#  #   Column      Dtype
# ---  ------      -----
#  0   store_id    object
#  1   item_id     object
#  2   wm_yr_wk    int64
#  3   sell_price  float64
# dtypes: float64(1), int64(1), object(2)
# memory usage: 208.8+ MB

# %%
sell_prices
# Out:
#         store_id        item_id  wm_yr_wk  sell_price
# 0           CA_1  HOBBIES_1_001     11325        9.58
# 1           CA_1  HOBBIES_1_001     11326        9.58
# 2           CA_1  HOBBIES_1_001     11327        8.26
# 3           CA_1  HOBBIES_1_001     11328        8.26
# 4           CA_1  HOBBIES_1_001     11329        8.26
# ...          ...            ...       ...         ...
# 6841116     WI_3    FOODS_3_827     11617        1.00
# 6841117     WI_3    FOODS_3_827     11618        1.00
# 6841118     WI_3    FOODS_3_827     11619        1.00
# 6841119     WI_3    FOODS_3_827     11620        1.00
# 6841120     WI_3    FOODS_3_827     11621        1.00
#
# [6841121 rows x 4 columns]

# %%
sell_prices.isna().sum()
# Out:
# store_id      0
# item_id       0
# wm_yr_wk      0
# sell_price    0
# dtype: int64

# %%
calendar=pd.read_csv('data/calendar.csv')

# %%
calendar.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1969 entries, 0 to 1968
# Data columns (total 14 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   date          1969 non-null   object
#  1   wm_yr_wk      1969 non-null   int64
#  2   weekday       1969 non-null   object
#  3   wday          1969 non-null   int64
#  4   month         1969 non-null   int64
#  5   year          1969 non-null   int64
#  6   d             1969 non-null   object
#  7   event_name_1  162 non-null    object
#  8   event_type_1  162 non-null    object
#  9   event_name_2  5 non-null      object
#  10  event_type_2  5 non-null      object
#  11  snap_CA       1969 non-null   int64
#  12  snap_TX       1969 non-null   int64
#  13  snap_WI       1969 non-null   int64
# dtypes: int64(7), object(7)
# memory usage: 215.5+ KB

# %%
calendar
# Out:
#             date  wm_yr_wk    weekday  wday  month  year       d  \
# 0     2011-01-29     11101   Saturday     1      1  2011     d_1
# 1     2011-01-30     11101     Sunday     2      1  2011     d_2
# 2     2011-01-31     11101     Monday     3      1  2011     d_3
# 3     2011-02-01     11101    Tuesday     4      2  2011     d_4
# 4     2011-02-02     11101  Wednesday     5      2  2011     d_5
# ...          ...       ...        ...   ...    ...   ...     ...
# 1964  2016-06-15     11620  Wednesday     5      6  2016  d_1965
# 1965  2016-06-16     11620   Thursday     6      6  2016  d_1966
# 1966  2016-06-17     11620     Friday     7      6  2016  d_1967
# 1967  2016-06-18     11621   Saturday     1      6  2016  d_1968
# 1968  2016-06-19     11621     Sunday     2      6  2016  d_1969
#
#       event_name_1 event_type_1  event_name_2 event_type_2  snap_CA  snap_TX  \
# 0              NaN          NaN           NaN          NaN        0        0
# ...
